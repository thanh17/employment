# %%
import pandas as pd
import random as rnd 
import mysql.connector
from mysql.connector import Error
import plotly
import json
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pymysql
import plotly.express as px
import plotly.graph_objects as go
from sqlalchemy import create_engine
import networkx as nx
from networkx_viewer import Viewer
from functools import reduce
from scipy.spatial.distance import pdist, squareform, cdist
import jgraph
from cyjupyter import Cytoscape
from scipy.stats import kendalltau
from scipy.stats import weightedtau
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import seaborn as sn

# %%
info_dict = {'descriptor_domain':['abilites','work_context','interests',
                               'knowledge','skills','work_styles','work_values','gwas','job_zones'],
            'starter':['IM,LV',None,'OI',None,None,'IM','EX',None,None],
            'change':[None,'CX',None,'IM, LV','IM, LV',None,None,'IM, LV','JZ']}
df_info = pd.DataFrame(data = info_dict)
df_info
# Out:
#   descriptor_domain starter  change
# 0          abilites   IM,LV    None
# 1      work_context    None      CX
# 2         interests      OI    None
# 3         knowledge    None  IM, LV
# 4            skills    None  IM, LV
# 5       work_styles      IM    None
# 6       work_values      EX    None
# 7              gwas    None  IM, LV
# 8         job_zones    None      JZ

# %%
connection = mysql.connector.connect(host='127.0.0.1',
                                         database='employment',
                                         user='root',
                                         password='thanhn123')

# %%
def get_data(connection, descriptor_domain,LV_only = False, filt = False):
    '''
    Return df in the SOCs-decriptor format of a specific domain 
    descriptor_domeain:
        work context
        knowledge
        skills
        gwas
        job_zones, filter
        Abilities, filter
    
    '''
    df= pd.DataFrame(data=None)
    if descriptor_domain == 'work_context':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_context
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'CX';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'job_zones':
        if filt:
            df= pd.read_sql('''
                SELECT title,job_zone FROM employment.job_zones
                LEFT JOIN employment.occupation_data USING (onetsoc_code); ''', con = connection)
            df = df[df['job_zone'].isin(val)]
        else:
            df= pd.read_sql('''
                SELECT title,job_zone FROM employment.job_zones
                LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
    elif descriptor_domain == 'abilities':
        if filt:
#             df= pd.read_sql('''
#             SELECT title, element_name, element_id,data_value FROM employment.''' + descriptor_domain + '''
#             LEFT JOIN employment.content_model_reference USING (element_id) 
#             LEFT JOIN employment.occupation_data USING (onetsoc_code); ''', con = connection)
#             df = df[df['element_id'].contains(val)]
            df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE element_id LIKE\''''+ val +'''%\'; ''', con = connection)
            
        else:
            df= pd.read_sql('''
            SELECT title, element_name,element_id, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
        df = df.groupby(by=['title','element_name'])['data_value'].mean()
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'work_values':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_values
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'EX';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'interests':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.interests
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'OI';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'work_styles':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_styles
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'IM';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'name':
        df= pd.read_sql('''
            SELECT * FROM employment.occupation_data;''', con = connection)
    else:
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
        if LV_only:
            df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE \"LV\";''', con = connection)
        df = df.groupby(by=['title','element_name'])['data_value'].mean()
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    return df

# %%
def distance_table(df, jz=False):
    
#     squareform(pdist(df.iloc[:, 1:])), columns=df.title.unique(), index=df.title.unique()
    dist = []
    name_dict = {}
    if jz:
        name_dict = df['title'].sort_values().reset_index()['title'].to_dict()
        dist = pdist(df[df.columns[1:]],'euclidean')
    else:
        for i in range(len(df.index)):
            name_dict[i] = df.index[i]
        dist = pdist(df,'euclidean') #Euclidean distance for 1XN
    df_dist = pd.DataFrame(squareform(dist)) #Euclidean distance for NxN
#     return df_dist
    columns = list(df_dist.index) 
    for i in range(len(df.index)): #convert 0 values to NaN
        df_dist.loc[i,i] = np.NaN
    mean = df_dist.mean().mean()
    std = df_dist.stack().std() 

    for col in columns: #Z-score calculated 
        df_dist[col] = (df_dist[col] - mean)/std
#     return df_dist
    return df_dist.rename(columns = name_dict, index = name_dict)

# %%
df_ab = get_data(connection,'abilities')
df_in = get_data(connection,'interests')
df_ws = get_data(connection,'work_styles')
df_wv = get_data(connection, 'work_values')
df_wc = get_data(connection,'work_context')
df_knowledge = get_data(connection,'knowledge')
df_gwas = get_data(connection,'work_activities')
df_jz = get_data(connection,'job_zones')
df_jz = df_jz[df_jz['title'] != 'Legislators']
df_skills = get_data(connection,'skills')

# %%
wc_dist = distance_table(df_wc)
knowledge_dist = distance_table(df_knowledge)
skills_dist = distance_table(df_skills)
gwas_dist = distance_table(df_gwas)
jz_dist = distance_table(df_jz,True)
wv_dist = distance_table(df_wv)
in_dist = distance_table(df_in)
ab_dist = distance_table(df_ab)
ws_dist = distance_table(df_ws)

# %%
# df_name = pd.read_sql('''
#             SELECT onetsoc_code,title FROM employment.occupation_data;''', con = connection)
# name_dict = df_name.set_index('onetsoc_code').to_dict()
# name_dict_cps = {}
# for val in name_dict['title']:
# #     print(val[:-3])
# #     break
#     name_dict_cps[val[:-3]] = name_dict['title'][val]

# %%
df_name = pd.read_csv('../CPS Job Changes/2010_to_2018_SOC_Crosswalk.csv')
df_name = df_name[['2018 SOC Code','2018 SOC Title']]
df_name = df_name.set_index('2018 SOC Code').to_dict()
df_name = df_name['2018 SOC Title']

# %%
df_cps = pd.read_csv('../CPS Job Changes/JobChanges_2011to19.csv')

# %%
df_cps
# Out:
#        ONET18_SOC_LY ONET18_SOC  \
# 0            11-1011    11-1021
# 1            11-1011    11-1031
# 2            11-1011    11-2021
# 3            11-1011    11-2022
# 4            11-1011    11-3012
# ...              ...        ...
# 115312       53-7199    53-7065
# 115313       53-7199    53-7071
# 115314       53-7199    53-7072
# 115315       53-7199    53-7073
# 115316       53-7199    53-7081
#
#                                             ONET18_Title  \
# 0                        General and Operations Managers
# 1                                            Legislators
# 2                                     Marketing Managers
# 3                                         Sales Managers
# 4                       Administrative Services Managers
# ...                                                  ...
# 115312                        Stockers and Order Fillers
# 115313  Gas Compressor and Gas Pumping Station Operators
# 115314           Pump Operators, Except Wellhead Pumpers
# 115315                                  Wellhead Pumpers
# 115316         Refuse and Recyclable Material Collectors
#
#                            ONET18_Title_LY          count   pct_tot  \
# 0                         Chief Executives  327891.330000  0.196284
# 1                         Chief Executives    4069.996250  0.002436
# 2                         Chief Executives    5621.145000  0.003365
# 3                         Chief Executives    5621.145000  0.003365
# 4                         Chief Executives    1832.805000  0.001097
# ...                                    ...            ...       ...
# 115312  Material Moving Workers, All Other    4878.226667  0.002920
# 115313  Material Moving Workers, All Other      35.795833  0.000021
# 115314  Material Moving Workers, All Other      35.795833  0.000021
# 115315  Material Moving Workers, All Other      35.795833  0.000021
# 115316  Material Moving Workers, All Other     437.930000  0.000262
#
#           count_socly  pct_socly  in_grp  in_minor_grp  in_broad_occ  \
# 0       644769.200000  50.854062       1             1             0
# 1       644769.200000   0.631233       1             1             0
# 2       644769.200000   0.871807       1             0             0
# 3       644769.200000   0.871807       1             0             0
# 4       644769.200000   0.284258       1             0             0
# ...               ...        ...     ...           ...           ...
# 115312   43481.721667  11.219028       1             0             0
# 115313   43481.721667   0.082324       1             0             0
# 115314   43481.721667   0.082324       1             0             0
# 115315   43481.721667   0.082324       1             0             0
# 115316   43481.721667   1.007159       1             0             0
#
#         employment_projection_NewJob  wage_change_BetweenJobs
# 0                                5.8               -45.365359
# 1                                6.2               -84.131579
# 2                                6.7               -25.811908
# 3                                3.5               -31.337393
# 4                                NaN                      NaN
# ...                              ...                      ...
# 115312                           0.7               -13.874346
# 115313                          -2.1               108.180628
# 115314                           9.7                41.688482
# 115315                           4.2                73.167539
# 115316                           8.8                19.044503
#
# [115317 rows x 13 columns]

# %%
df_all = pd.read_csv('../CPS Job Changes/GoodnessIndicators_allCombinations.csv')
df_all = df_all.replace({'SOC2018_origin':df_name, 'SOC2018_destination':df_name})

# %%
df_all[(df_all['SOC2018_origin'] == 'Chief Executives') & (df_all['SOC2018_destination'] == 'General and Operations Managers')]
# Out:
#        SOC2018_origin              SOC2018_destination  median_h_wage_o  \
# 544  Chief Executives  General and Operations Managers            48.45
#
#      median_h_wage_d  median_h_wage_d.1  employment_projection_NewJob  \
# 544            -10.0              88.68                         -10.0
#
#      wage_change_BetweenJobs
# 544                83.034056

# %% [markdown]
# ## drop values based on <0 or < std

# %%
def exact_difference(df):
    '''
    return adjacency matrix difference. Difference is based on column - row
    zeroed out 
    '''
    ini_array1 = df.values - df.values[:, None]
    arr = ini_array1[ini_array1 <0] = 0
    arr = np.sqrt(np.mean(np.power(ini_array1,1),axis =2))
#     return arr
    new_df = pd.concat((df.reset_index()['title'], pd.DataFrame(arr, columns=df.reset_index()['title'])), axis=1)
    return new_df

# %%
def get_df_comparison(df_onet,df_cps,good_dict,occ,top):
    '''
    return df of comparisons of different occupations
    
    '''
    comparison = {'ONET_occ_before':[],'ONET_occ_after':[],'ONET_employment_proj' : [],
                       'ONET_wage_change':[],'CPS_occ_before': [],'CPS_occ_after': [],'CPS_employment_proj' : [],'CPS_wage_change':[]}
    
    df_cps_iter = df_cps[df_cps['ONET18_Title_LY'] == occ].sort_values(by = 'pct_tot', ascending = False)[0:top]
    df_onet_iter = df_onet.loc[occ].sort_values()[1:top+1].to_frame()
    
    for row in df_cps_iter.iterrows():
        if (occ,row[1][2]) not in good_dict:
            comparison['CPS_occ_before'].append(occ)
            comparison['CPS_occ_after'].append(row[1][2])
            comparison['CPS_employment_proj'].append(None)
            comparison['CPS_wage_change'].append(None)
        else:
            comparison['CPS_occ_before'].append(occ)
            comparison['CPS_occ_after'].append(row[1][2])
            comparison['CPS_employment_proj'].append(good_dict[(occ,row[1][2])][0])
            comparison['CPS_wage_change'].append(good_dict[(occ,row[1][2])][1])
    for row in df_onet_iter.iterrows():
        if (occ,row[0]) not in good_dict:
            comparison['ONET_occ_before'].append(occ)
            comparison['ONET_occ_after'].append(row[0])
            comparison['ONET_employment_proj'].append(None)
            comparison['ONET_wage_change'].append(None)
        else:
            comparison['ONET_occ_before'].append(occ)
            comparison['ONET_occ_after'].append(row[0])
            comparison['ONET_employment_proj'].append(good_dict[(occ,row[0])][0])
            comparison['ONET_wage_change'].append(good_dict[(occ,row[0])][1])
    return pd.DataFrame(comparison)

# %%
difference_abilites = exact_difference(df_ab)
# difference_in = exact_difference(df_in)
# difference_ws = exact_difference(df_ws)
# difference_wv =exact_difference(df_wv)
# difference_wc =exact_difference(df_wc)
# difference_knowledge =exact_difference(df_knowledge)
difference_gwas =exact_difference(df_gwas)
# difference_jz =exact_difference(df_jz)
difference_skills =exact_difference(df_skills)

# %%
difference_skills.index = difference_skills.title 
difference_abilites.index = difference_abilites.title 
difference_gwas.index = difference_gwas.title 

difference_skills = difference_skills.drop(['title'],axis =1)
difference_abilites = difference_abilites.drop(['title'],axis =1)
difference_gwas = difference_gwas.drop(['title'],axis =1)

# %% [markdown]
# ## Not dropping values

# %%
df_concat = pd.concat([ab_dist,skills_dist,gwas_dist]).groupby(level =0).mean()

# %% [markdown]
# ## dropping values

# %%
df_concat_exact_difference = pd.concat([difference_gwas,difference_skills,difference_abilites]).groupby(level =0).mean()

# %% [markdown]
# ## CPS data

# %%
df_cps[:10]
# Out:
#   ONET18_SOC_LY ONET18_SOC                               ONET18_Title  \
# 0       11-1011    11-1021            General and Operations Managers
# 1       11-1011    11-1031                                Legislators
# 2       11-1011    11-2021                         Marketing Managers
# 3       11-1011    11-2022                             Sales Managers
# 4       11-1011    11-3012           Administrative Services Managers
# 5       11-1011    11-3013                        Facilities Managers
# 6       11-1011    11-3013                        Facilities Managers
# 7       11-1011    11-3021  Computer and Information Systems Managers
# 8       11-1011    11-3031                         Financial Managers
# 9       11-1011    11-3121                   Human Resources Managers
#
#     ONET18_Title_LY         count   pct_tot  count_socly  pct_socly  in_grp  \
# 0  Chief Executives  327891.33000  0.196284     644769.2  50.854062       1
# 1  Chief Executives    4069.99625  0.002436     644769.2   0.631233       1
# 2  Chief Executives    5621.14500  0.003365     644769.2   0.871807       1
# 3  Chief Executives    5621.14500  0.003365     644769.2   0.871807       1
# 4  Chief Executives    1832.80500  0.001097     644769.2   0.284258       1
# 5  Chief Executives    1832.80500  0.001097     644769.2   0.284258       1
# 6  Chief Executives    4069.99625  0.002436     644769.2   0.631233       1
# 7  Chief Executives   15549.97000  0.009309     644769.2   2.411711       1
# 8  Chief Executives   18203.95000  0.010897     644769.2   2.823328       1
# 9  Chief Executives    7273.10000  0.004354     644769.2   1.128016       1
#
#    in_minor_grp  in_broad_occ  employment_projection_NewJob  \
# 0             1             0                           5.8
# 1             1             0                           6.2
# 2             0             0                           6.7
# 3             0             0                           3.5
# 4             0             0                           NaN
# 5             0             0                           NaN
# 6             0             0                           NaN
# 7             0             0                          10.4
# 8             0             0                          15.5
# 9             0             0                           6.3
#
#    wage_change_BetweenJobs
# 0               -45.365359
# 1               -84.131579
# 2               -25.811908
# 3               -31.337393
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7               -20.647271
# 8               -29.578259
# 9               -36.727560

# %%
df_all
# Out:
#           SOC2018_origin                                SOC2018_destination  \
# 0       Chief Executives                  Correctional Officers and Jailers
# 1       Chief Executives      Environmental Science Teachers, Postsecondary
# 2       Chief Executives                               School Psychologists
# 3       Chief Executives  Human Resources Assistants, Except Payroll and...
# 4       Chief Executives                        Human Resources Specialists
# ...                  ...                                                ...
# 752635               NaN                                            39-7010
# 752636               NaN                                            53-6098
# 752637               NaN                                            29-1228
# 752638               NaN                                            15-1256
# 752639               NaN                                            29-2040
#
#         median_h_wage_o  median_h_wage_d  median_h_wage_d.1  \
# 0             21.720000            -10.0              88.68
# 1             39.629808            -10.0              88.68
# 2                   NaN            -10.0              88.68
# 3             19.920000            -10.0              88.68
# 4             29.770000            -10.0              88.68
# ...                 ...              ...                ...
# 752635        13.270000              NaN                NaN
# 752636        17.790000              NaN                NaN
# 752637        99.280000              NaN                NaN
# 752638        51.690000              NaN                NaN
# 752639        17.020000              NaN                NaN
#
#         employment_projection_NewJob  wage_change_BetweenJobs
# 0                              -10.0               308.287293
# 1                              -10.0               123.770957
# 2                              -10.0                      NaN
# 3                              -10.0               345.180723
# 4                              -10.0               197.883776
# ...                              ...                      ...
# 752635                           NaN                      NaN
# 752636                           NaN                      NaN
# 752637                           NaN                      NaN
# 752638                           NaN                      NaN
# 752639                           NaN                      NaN
#
# [752640 rows x 7 columns]

# %%
for row in df_cps.iterrows():
    print(row)
    print(row[1][0],row[1][1])
    print(row[1][-2],row[1][-1])
    break
# Out:
# (0, ONET18_SOC_LY                                           11-1011
# ONET18_SOC                                              11-1021
# ONET18_Title                    General and Operations Managers
# ONET18_Title_LY                                Chief Executives
# count                                                    327891
# pct_tot                                                0.196284
# count_socly                                              644769
# pct_socly                                               50.8541
# in_grp                                                        1
# in_minor_grp                                                  1
# in_broad_occ                                                  0
# employment_projection_NewJob                                5.8
# wage_change_BetweenJobs                                -45.3654
# Name: 0, dtype: object)
# 11-1011 11-1021
# 5.8 -45.36535859269279

# %%
for row in df_all.iterrows():
    print(row)
    print(row[1][0],row[1][1])
    print(row[1][-2],row[1][-1])
    break
# Out:
# (0, SOC2018_origin                                   Chief Executives
# SOC2018_destination             Correctional Officers and Jailers
# median_h_wage_o                                             21.72
# median_h_wage_d                                               -10
# median_h_wage_d.1                                           88.68
# employment_projection_NewJob                                  -10
# wage_change_BetweenJobs                                   308.287
# Name: 0, dtype: object)
# Chief Executives Correctional Officers and Jailers
# -10.0 308.28729281768

# %%
good_dict = {}
for row in df_cps.iterrows():

    #(ONET18_Title_LY,ONET18_Title) = [employment_projection_NewJob,wage_change_BetweenJobs]
    good_dict[(row[1][3],row[1][2])] = [row[1][-2],row[1][-1]]

# %%
good_dict[('Chief Executives', 'General and Operations Managers')]
# Out:
# [5.8, -45.36535859269279]

# %% [markdown]
# ## all data

# %%
good_dict_new = {}
i =0
for row in df_all.iterrows():
    good_dict_new[(row[1][0],row[1][1])] = [row[1][-2],row[1][-1]]

# %%
good_dict_new[('Chief Executives', 'General and Operations Managers')]
# Out:
# [-10.0, 83.0340557275542]

# %%
# good_dict_new[('Chief Executives', 'General and Operations Managers')]

# %% [markdown]
# ## No Drop

# %%
get_df_comparison(df_concat,df_cps,good_dict,'Registered Nurses',10)
# Out:
#      ONET_occ_before                                     ONET_occ_after  \
# 0  Registered Nurses  Licensed Practical and Licensed Vocational Nurses
# 1  Registered Nurses                                Physical Therapists
# 2  Registered Nurses                                  Athletic Trainers
# 3  Registered Nurses                                Nurse Practitioners
# 4  Registered Nurses                                           Midwives
# 5  Registered Nurses                             Exercise Physiologists
# 6  Registered Nurses                                      Veterinarians
# 7  Registered Nurses                                     Nurse Midwives
# 8  Registered Nurses                               Physician Assistants
# 9  Registered Nurses                                         Urologists
#
#    ONET_employment_proj  ONET_wage_change     CPS_occ_before  \
# 0                   9.1        -35.215664  Registered Nurses
# 1                  18.2         22.020431  Registered Nurses
# 2                  16.2        -33.914695  Registered Nurses
# 3                  52.4         49.829739  Registered Nurses
# 4                   NaN               NaN  Registered Nurses
# 5                  11.3        -32.917140  Registered Nurses
# 6                  15.9         30.249716  Registered Nurses
# 7                  11.6         43.303065  Registered Nurses
# 8                  31.3         53.149830  Registered Nurses
# 9                   NaN               NaN  Registered Nurses
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                                Physical Therapists                 18.2
# 1                             Respiratory Therapists                 19.4
# 2                              Therapists, All Other                 14.6
# 3                             Exercise Physiologists                 11.3
# 4                       Speech-Language Pathologists                 24.9
# 5                            Occupational Therapists                 15.9
# 6                                     Nurse Midwives                 11.6
# 7                                Nurse Practitioners                 52.4
# 8  Licensed Practical and Licensed Vocational Nurses                  9.1
# 9                                 Nurse Anesthetists                 13.7
#
#    CPS_wage_change
# 0        22.020431
# 1       -16.345062
# 2       -28.178207
# 3       -32.917140
# 4         7.945516
# 5        15.891033
# 6        43.303065
# 7        49.829739
# 8       -35.215664
# 9       138.450624

# %%
get_df_comparison(df_concat,df_cps,good_dict_new,'Retail Salespersons',10)
# Out:
#        ONET_occ_before                                     ONET_occ_after  \
# 0  Retail Salespersons               Hotel, Motel, and Resort Desk Clerks
# 1  Retail Salespersons                                           Cashiers
# 2  Retail Salespersons                          Counter and Rental Clerks
# 3  Retail Salespersons                             Waiters and Waitresses
# 4  Retail Salespersons                              Postal Service Clerks
# 5  Retail Salespersons                          Stock Clerks, Sales Floor
# 6  Retail Salespersons                                            Tellers
# 7  Retail Salespersons                                         Bartenders
# 8  Retail Salespersons  Sales Representatives, Wholesale and Manufactu...
# 9  Retail Salespersons  Reservation and Transportation Ticket Agents a...
#
#    ONET_employment_proj  ONET_wage_change       CPS_occ_before  \
# 0                  -0.6          3.231293  Retail Salespersons
# 1                  -0.6          6.772208  Retail Salespersons
# 2                  -0.6        -12.409810  Retail Salespersons
# 3                  -0.6         10.363640  Retail Salespersons
# 4                  -0.6        -47.739990  Retail Salespersons
# 5                   NaN               NaN  Retail Salespersons
# 6                  -0.6        -19.174430  Retail Salespersons
# 7                  -0.6          6.584723  Retail Salespersons
# 8                  -0.6        -57.861850  Retail Salespersons
# 9                  -0.6        -34.200540  Retail Salespersons
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                                           Cashiers                 -0.6
# 1         Gambling Change Persons and Booth Cashiers                 -0.6
# 2                             Insurance Sales Agents                 -0.6
# 3  Sales Representatives of Services, Except Adve...                 -0.6
# 4               Sales and Related Workers, All Other                 -0.6
# 5  Sales Representatives, Wholesale and Manufactu...                 -0.6
# 6  Sales Representatives, Wholesale and Manufactu...                 -0.6
# 7                           Real Estate Sales Agents                 -0.6
# 8                                Real Estate Brokers                 -0.6
# 9               Receptionists and Information Clerks                 -0.6
#
#    CPS_wage_change
# 0         6.772208
# 1        -1.700405
# 2       -50.428750
# 3       -55.020380
# 4       -20.653590
# 5       -68.831840
# 6       -57.861850
# 7       -48.406290
# 8       -57.715080
# 9       -15.986160

# %%
get_df_comparison(df_concat,df_cps,good_dict_new,'Janitors and Cleaners, Except Maids and Housekeeping Cleaners',10)
# Out:
#                                      ONET_occ_before  \
# 0  Janitors and Cleaners, Except Maids and Housek...
# 1  Janitors and Cleaners, Except Maids and Housek...
# 2  Janitors and Cleaners, Except Maids and Housek...
# 3  Janitors and Cleaners, Except Maids and Housek...
# 4  Janitors and Cleaners, Except Maids and Housek...
# 5  Janitors and Cleaners, Except Maids and Housek...
# 6  Janitors and Cleaners, Except Maids and Housek...
# 7  Janitors and Cleaners, Except Maids and Housek...
# 8  Janitors and Cleaners, Except Maids and Housek...
# 9  Janitors and Cleaners, Except Maids and Housek...
#
#                                       ONET_occ_after  ONET_employment_proj  \
# 0                                             Tapers                  -4.0
# 1                   Laundry and Dry-Cleaning Workers                   0.2
# 2                      Slaughterers and Meat Packers                   3.3
# 3                 Cleaners of Vehicles and Equipment                   3.6
# 4  Helpers--Painters, Paperhangers, Plasterers, a...                   1.9
# 5             Shoe and Leather Workers and Repairers                   NaN
# 6                              Solderers and Brazers                   NaN
# 7                                       Paperhangers                  -0.8
# 8  Pressers, Textile, Garment, and Related Materials                   NaN
# 9  Postal Service Mail Sorters, Processors, and P...                   NaN
#
#    ONET_wage_change                                     CPS_occ_before  \
# 0        115.314632  Janitors and Cleaners, Except Maids and Housek...
# 1        -11.751327  Janitors and Cleaners, Except Maids and Housek...
# 2          6.520091  Janitors and Cleaners, Except Maids and Housek...
# 3         -5.989386  Janitors and Cleaners, Except Maids and Housek...
# 4         14.253222  Janitors and Cleaners, Except Maids and Housek...
# 5               NaN  Janitors and Cleaners, Except Maids and Housek...
# 6               NaN  Janitors and Cleaners, Except Maids and Housek...
# 7         47.687642  Janitors and Cleaners, Except Maids and Housek...
# 8               NaN  Janitors and Cleaners, Except Maids and Housek...
# 9               NaN  Janitors and Cleaners, Except Maids and Housek...
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                    Maids and Housekeeping Cleaners                 -0.3
# 1             Landscaping and Groundskeeping Workers                 10.1
# 2  Pesticide Handlers, Sprayers, and Applicators,...                  8.3
# 3             Grounds Maintenance Workers, All Other                  6.5
# 4                          Tree Trimmers and Pruners                 10.7
# 5                               Pest Control Workers                  8.5
# 6                              Construction Laborers                  5.4
# 7                                Retail Salespersons                 -0.6
# 8                                  Childcare Workers                  1.7
# 9  Laborers and Freight, Stock, and Material Move...                  4.2
#
#    CPS_wage_change
# 0        -9.401061
# 1        10.917362
# 2        30.629265
# 3        16.982563
# 4        45.716452
# 5        36.087945
# 6        34.344200
# 7        -7.960576
# 8       -11.675512
# 9         7.581501

# %% [markdown]
# ## Drop

# %%
get_df_comparison(df_concat_exact_difference,df_cps,good_dict_new,'Registered Nurses',10)
# Out:
#      ONET_occ_before                                     ONET_occ_after  \
# 0  Registered Nurses  Locker Room, Coatroom, and Dressing Room Atten...
# 1  Registered Nurses                                 Teacher Assistants
# 2  Registered Nurses                             Office Clerks, General
# 3  Registered Nurses                                  Childcare Workers
# 4  Registered Nurses                 Insurance Policy Processing Clerks
# 5  Registered Nurses                      Proofreaders and Copy Markers
# 6  Registered Nurses                                     License Clerks
# 7  Registered Nurses                                Telephone Operators
# 8  Registered Nurses  Counter Attendants, Cafeteria, Food Concession...
# 9  Registered Nurses                            Insurance Claims Clerks
#
#    ONET_employment_proj  ONET_wage_change     CPS_occ_before  \
# 0                   7.2        191.963546  Registered Nurses
# 1                   NaN               NaN  Registered Nurses
# 2                   7.2        115.271839  Registered Nurses
# 3                   7.2        202.489270  Registered Nurses
# 4                   NaN               NaN  Registered Nurses
# 5                   7.2         80.348004  Registered Nurses
# 6                   NaN               NaN  Registered Nurses
# 7                   7.2        105.002909  Registered Nurses
# 8                   NaN               NaN  Registered Nurses
# 9                   NaN               NaN  Registered Nurses
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                                Physical Therapists                  7.2
# 1                             Respiratory Therapists                  7.2
# 2                              Therapists, All Other                  7.2
# 3                             Exercise Physiologists                  7.2
# 4                       Speech-Language Pathologists                  7.2
# 5                            Occupational Therapists                  7.2
# 6                                     Nurse Midwives                  7.2
# 7                                Nurse Practitioners                  7.2
# 8  Licensed Practical and Licensed Vocational Nurses                  7.2
# 9                                 Nurse Anesthetists                  7.2
#
#    CPS_wage_change
# 0       -18.046512
# 1        19.538670
# 2        39.233505
# 3        49.069374
# 4        -7.360673
# 5       -13.712047
# 6       -30.217822
# 7       -33.257576
# 8        54.358300
# 9       -58.062597

# %%
get_df_comparison(df_concat_exact_difference,df_cps,good_dict_new,'Retail Salespersons',10)
# Out:
#        ONET_occ_before                                     ONET_occ_after  \
# 0  Retail Salespersons  Locker Room, Coatroom, and Dressing Room Atten...
# 1  Retail Salespersons  Hosts and Hostesses, Restaurant, Lounge, and C...
# 2  Retail Salespersons                                      Telemarketers
# 3  Retail Salespersons                                             Models
# 4  Retail Salespersons                                     Gaming Dealers
# 5  Retail Salespersons        Ushers, Lobby Attendants, and Ticket Takers
# 6  Retail Salespersons                        Manicurists and Pedicurists
# 7  Retail Salespersons                                   Cooks, Fast Food
# 8  Retail Salespersons                                 Teacher Assistants
# 9  Retail Salespersons  Counter Attendants, Cafeteria, Food Concession...
#
#    ONET_employment_proj  ONET_wage_change       CPS_occ_before  \
# 0                  -0.6          0.579950  Retail Salespersons
# 1                  -0.6          9.369369  Retail Salespersons
# 2                  -0.6         -3.955696  Retail Salespersons
# 3                  -0.6        -10.931770  Retail Salespersons
# 4                   NaN               NaN  Retail Salespersons
# 5                  -0.6          7.433628  Retail Salespersons
# 6                  -0.6         -2.017756  Retail Salespersons
# 7                  -0.6          7.433628  Retail Salespersons
# 8                   NaN               NaN  Retail Salespersons
# 9                   NaN               NaN  Retail Salespersons
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                                           Cashiers                 -0.6
# 1         Gambling Change Persons and Booth Cashiers                 -0.6
# 2                             Insurance Sales Agents                 -0.6
# 3  Sales Representatives of Services, Except Adve...                 -0.6
# 4               Sales and Related Workers, All Other                 -0.6
# 5  Sales Representatives, Wholesale and Manufactu...                 -0.6
# 6  Sales Representatives, Wholesale and Manufactu...                 -0.6
# 7                           Real Estate Sales Agents                 -0.6
# 8                                Real Estate Brokers                 -0.6
# 9               Receptionists and Information Clerks                 -0.6
#
#    CPS_wage_change
# 0         6.772208
# 1        -1.700405
# 2       -50.428750
# 3       -55.020380
# 4       -20.653590
# 5       -68.831840
# 6       -57.861850
# 7       -48.406290
# 8       -57.715080
# 9       -15.986160

# %%
get_df_comparison(df_concat_exact_difference,df_cps,good_dict_new,'Janitors and Cleaners, Except Maids and Housekeeping Cleaners',10)
# Out:
#                                      ONET_occ_before  \
# 0  Janitors and Cleaners, Except Maids and Housek...
# 1  Janitors and Cleaners, Except Maids and Housek...
# 2  Janitors and Cleaners, Except Maids and Housek...
# 3  Janitors and Cleaners, Except Maids and Housek...
# 4  Janitors and Cleaners, Except Maids and Housek...
# 5  Janitors and Cleaners, Except Maids and Housek...
# 6  Janitors and Cleaners, Except Maids and Housek...
# 7  Janitors and Cleaners, Except Maids and Housek...
# 8  Janitors and Cleaners, Except Maids and Housek...
# 9  Janitors and Cleaners, Except Maids and Housek...
#
#                                       ONET_occ_after  ONET_employment_proj  \
# 0                                             Models                   4.4
# 1  Locker Room, Coatroom, and Dressing Room Atten...                   4.4
# 2                 Cleaners of Vehicles and Equipment                   4.4
# 3                    Maids and Housekeeping Cleaners                   4.4
# 4             Shoe and Leather Workers and Repairers                   4.4
# 5         Graders and Sorters, Agricultural Products                   4.4
# 6                      Slaughterers and Meat Packers                   4.4
# 7                        Manicurists and Pedicurists                   4.4
# 8                              Solderers and Brazers                   NaN
# 9                                   Cooks, Fast Food                   4.4
#
#    ONET_wage_change                                     CPS_occ_before  \
# 0         -3.228173  Janitors and Cleaners, Except Maids and Housek...
# 1          9.279205  Janitors and Cleaners, Except Maids and Housek...
# 2          6.370968  Janitors and Cleaners, Except Maids and Housek...
# 3         10.376570  Janitors and Cleaners, Except Maids and Housek...
# 4         -7.178044  Janitors and Cleaners, Except Maids and Housek...
# 5          6.888169  Janitors and Cleaners, Except Maids and Housek...
# 6         -6.120996  Janitors and Cleaners, Except Maids and Housek...
# 7          6.456820  Janitors and Cleaners, Except Maids and Housek...
# 8               NaN  Janitors and Cleaners, Except Maids and Housek...
# 9         16.725660  Janitors and Cleaners, Except Maids and Housek...
#
#                                        CPS_occ_after  CPS_employment_proj  \
# 0                    Maids and Housekeeping Cleaners                  4.4
# 1             Landscaping and Groundskeeping Workers                  4.4
# 2  Pesticide Handlers, Sprayers, and Applicators,...                  4.4
# 3             Grounds Maintenance Workers, All Other                  4.4
# 4                          Tree Trimmers and Pruners                  4.4
# 5                               Pest Control Workers                  4.4
# 6                              Construction Laborers                  4.4
# 7                                Retail Salespersons                  4.4
# 8                                  Childcare Workers                  4.4
# 9  Laborers and Freight, Stock, and Material Move...                  4.4
#
#    CPS_wage_change
# 0        10.376570
# 1        -9.842789
# 2       -23.447480
# 3       -14.517170
# 4       -31.373570
# 5       -26.518110
# 6       -25.564330
# 7         8.649094
# 8        13.218880
# 9        -7.047216
