# %%
import pandas as pd
import random as rnd 
import mysql.connector
from mysql.connector import Error
import plotly
import json
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pymysql
import plotly.express as px
import plotly.graph_objects as go
from sqlalchemy import create_engine
import networkx as nx
from networkx_viewer import Viewer
from scipy.spatial.distance import pdist, squareform
import igraph
import sklearn
from sklearn.cluster import KMeans
from functools import reduce

# %% [markdown]
# ## Get data from SQL servers

# %%
connection = mysql.connector.connect(host='localhost',
                                         database='employment',
                                         user='root',
                                         password='1234')

# %%
def get_data(connection, descriptor_domain,filt = False,val = None):
    '''
    Return df in the SOCs-decriptor format of a specific domain 
    descriptor_domeain:
        work context
        knowledge
        skills
        gwas
        job_zones, filter
        Abilities, filter
    
    '''
    df= pd.DataFrame(data=None)
    if descriptor_domain == 'work_context':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_context
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'CX';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'job_zones':
        if filt:
            df= pd.read_sql('''
                SELECT title,job_zone FROM employment.job_zones
                LEFT JOIN employment.occupation_data USING (onetsoc_code); ''', con = connection)
            df = df[df['job_zone'].isin(val)]
        else:
            df= pd.read_sql('''
                SELECT title,job_zone FROM employment.job_zones
                LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
    elif descriptor_domain == 'abilities':
        if filt:
            df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE element_id LIKE\''''+ val +'''%\'; ''', con = connection)
            
        else:
            df= pd.read_sql('''
            SELECT title, element_name,element_id, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
        df = df.groupby(by=['title','element_name'])['data_value'].mean()
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'work_values':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_values
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'EX';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'interests':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.interests
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'OI';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'work_styles':
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.work_styles
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code)
            WHERE scale_id LIKE 'IM';''', con = connection)
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    elif descriptor_domain == 'name':
        df= pd.read_sql('''
            SELECT * FROM employment.occupation_data;''', con = connection)
    else:
        df= pd.read_sql('''
            SELECT title, element_name, data_value FROM employment.''' + descriptor_domain + '''
            LEFT JOIN employment.content_model_reference USING (element_id) 
            LEFT JOIN employment.occupation_data USING (onetsoc_code);''', con = connection)
        df = df.groupby(by=['title','element_name'])['data_value'].mean()
        df = df.reset_index().pivot(index = 'title', columns = 'element_name', values = 'data_value')
    return df

# %% [markdown]
# ## Calculating euclidean distance

# %%
# def distance_table(df, jz=False, Z = False):
#     '''
#     @param df: dataframe of 
    
#     '''
# #     squareform(pdist(df.iloc[:, 1:])), columns=df.title.unique(), index=df.title.unique()
#     dist = []
#     name_dict = {}
#     if jz:
#         name_dict = df['title'].sort_values().reset_index()['title'].to_dict()
#         dist = pdist(df[df.columns[1:]],'euclidean') #Euclidean distance for 1XN
#     else:
#         for i in range(len(df.index)):
#             name_dict[i] = df.index[i]
#         dist = pdist(df,'euclidean') #Euclidean distance for 1XN
#     df_dist = pd.DataFrame(squareform(dist)) #Euclidean distance for NxN
# #     return df_dist
#     columns = list(df_dist.index) 
#     for i in range(len(df.index)): #convert 0 values to NaN
#         df_dist.loc[i,i] = np.NaN
#     mean = df_dist.mean().mean()
#     std = df_dist.stack().std() 
    
#     if Z:
#         for col in columns: #Z-score calculated 
#             df_dist[col] = (df_dist[col] - mean)/std
# #     return df_dist
#     return df_dist.rename(columns = name_dict, index = name_dict)

# %%
df_skills = get_data(connection,'skills')

df_ab = get_data(connection,'abilities')

df_wc = get_data(connection,'work_context')

df_knowledge = get_data(connection,'knowledge')

df_gwas = get_data(connection,'work_activities')

df_jz = get_data(connection,'job_zones')
df_jz = df_jz[df_jz['title'] != 'Legislators']
# df_skills[:10]

# %%
df_skills
# Out:
# element_name                                        Active Learning  \
# title
# Accountants                                                   3.185
# Actors                                                        2.620
# Actuaries                                                     3.750
# Acupuncturists                                                3.310
# Acute Care Nurses                                             3.815
# ...                                                             ...
# Wind Energy Project Managers                                  3.690
# Wind Turbine Service Technicians                              2.940
# Woodworking Machine Setters, Operators, and Ten...            2.310
# Word Processors and Typists                                   2.125
# Zoologists and Wildlife Biologists                            3.750
#
# element_name                                        Active Listening  \
# title
# Accountants                                                    3.940
# Actors                                                         3.685
# Actuaries                                                      4.060
# Acupuncturists                                                 3.685
# Acute Care Nurses                                              3.940
# ...                                                              ...
# Wind Energy Project Managers                                   3.750
# Wind Turbine Service Technicians                               3.065
# Woodworking Machine Setters, Operators, and Ten...             2.815
# Word Processors and Typists                                    3.185
# Zoologists and Wildlife Biologists                             4.000
#
# element_name                                        Complex Problem Solving  \
# title
# Accountants                                                           3.185
# Actors                                                                2.750
# Actuaries                                                             4.310
# Acupuncturists                                                        3.125
# Acute Care Nurses                                                     3.750
# ...                                                                     ...
# Wind Energy Project Managers                                          3.315
# Wind Turbine Service Technicians                                      3.190
# Woodworking Machine Setters, Operators, and Ten...                    2.625
# Word Processors and Typists                                           2.000
# Zoologists and Wildlife Biologists                                    3.750
#
# element_name                                        Coordination  \
# title
# Accountants                                                3.000
# Actors                                                     2.940
# Actuaries                                                  3.000
# Acupuncturists                                             2.940
# Acute Care Nurses                                          3.815
# ...                                                          ...
# Wind Energy Project Managers                               3.750
# Wind Turbine Service Technicians                           3.250
# Woodworking Machine Setters, Operators, and Ten...         2.060
# Word Processors and Typists                                2.370
# Zoologists and Wildlife Biologists                         3.370
#
# element_name                                        Critical Thinking  \
# title
# Accountants                                                     3.815
# Actors                                                          3.000
# Actuaries                                                       4.500
# Acupuncturists                                                  3.815
# Acute Care Nurses                                               4.000
# ...                                                               ...
# Wind Energy Project Managers                                    4.125
# Wind Turbine Service Technicians                                3.310
# Woodworking Machine Setters, Operators, and Ten...              2.940
# Word Processors and Typists                                     2.625
# Zoologists and Wildlife Biologists                              4.060
#
# element_name                                        Equipment Maintenance  \
# title
# Accountants                                                          0.50
# Actors                                                               0.50
# Actuaries                                                            0.50
# Acupuncturists                                                       0.50
# Acute Care Nurses                                                    0.50
# ...                                                                   ...
# Wind Energy Project Managers                                         0.75
# Wind Turbine Service Technicians                                     3.56
# Woodworking Machine Setters, Operators, and Ten...                   3.00
# Word Processors and Typists                                          1.12
# Zoologists and Wildlife Biologists                                   0.50
#
# element_name                                        Equipment Selection  \
# title
# Accountants                                                       0.500
# Actors                                                            0.500
# Actuaries                                                         0.500
# Acupuncturists                                                    0.875
# Acute Care Nurses                                                 1.440
# ...                                                                 ...
# Wind Energy Project Managers                                      0.815
# Wind Turbine Service Technicians                                  2.750
# Woodworking Machine Setters, Operators, and Ten...                2.690
# Word Processors and Typists                                       0.620
# Zoologists and Wildlife Biologists                                0.500
#
# element_name                                        Installation  Instructing  \
# title
# Accountants                                                0.500        2.815
# Actors                                                     0.500        2.685
# Actuaries                                                  0.500        3.250
# Acupuncturists                                             0.500        2.685
# Acute Care Nurses                                          0.500        3.690
# ...                                                          ...          ...
# Wind Energy Project Managers                               0.500        3.065
# Wind Turbine Service Technicians                           1.500        3.000
# Woodworking Machine Setters, Operators, and Ten...         1.565        1.815
# Word Processors and Typists                                0.500        1.500
# Zoologists and Wildlife Biologists                         0.500        3.125
#
# element_name                                        Judgment and Decision Making  \
# title
# Accountants                                                                3.500
# Actors                                                                     2.940
# Actuaries                                                                  4.500
# Acupuncturists                                                             3.500
# Acute Care Nurses                                                          3.875
# ...                                                                          ...
# Wind Energy Project Managers                                               3.560
# Wind Turbine Service Technicians                                           3.060
# Woodworking Machine Setters, Operators, and Ten...                         2.500
# Word Processors and Typists                                                2.190
# Zoologists and Wildlife Biologists                                         3.815
#
# element_name                                        ...  Science  \
# title                                               ...
# Accountants                                         ...    1.750
# Actors                                              ...    1.000
# Actuaries                                           ...    2.060
# Acupuncturists                                      ...    2.370
# Acute Care Nurses                                   ...    3.060
# ...                                                 ...      ...
# Wind Energy Project Managers                        ...    1.435
# Wind Turbine Service Technicians                    ...    2.060
# Woodworking Machine Setters, Operators, and Ten...  ...    1.000
# Word Processors and Typists                         ...    0.500
# Zoologists and Wildlife Biologists                  ...    3.940
#
# element_name                                        Service Orientation  \
# title
# Accountants                                                       3.000
# Actors                                                            2.185
# Actuaries                                                         3.000
# Acupuncturists                                                    3.500
# Acute Care Nurses                                                 3.940
# ...                                                                 ...
# Wind Energy Project Managers                                      3.000
# Wind Turbine Service Technicians                                  2.315
# Woodworking Machine Setters, Operators, and Ten...                1.630
# Word Processors and Typists                                       2.690
# Zoologists and Wildlife Biologists                                3.000
#
# element_name                                        Social Perceptiveness  \
# title
# Accountants                                                         3.000
# Actors                                                              3.750
# Actuaries                                                           2.880
# Acupuncturists                                                      3.685
# Acute Care Nurses                                                   4.310
# ...                                                                   ...
# Wind Energy Project Managers                                        3.560
# Wind Turbine Service Technicians                                    2.625
# Woodworking Machine Setters, Operators, and Ten...                  2.125
# Word Processors and Typists                                         2.560
# Zoologists and Wildlife Biologists                                  3.185
#
# element_name                                        Speaking  \
# title
# Accountants                                            3.750
# Actors                                                 3.940
# Actuaries                                              3.940
# Acupuncturists                                         3.560
# Acute Care Nurses                                      4.000
# ...                                                      ...
# Wind Energy Project Managers                           3.815
# Wind Turbine Service Technicians                       3.000
# Woodworking Machine Setters, Operators, and Ten...     2.750
# Word Processors and Typists                            2.940
# Zoologists and Wildlife Biologists                     3.880
#
# element_name                                        Systems Analysis  \
# title
# Accountants                                                    3.435
# Actors                                                         1.810
# Actuaries                                                      4.190
# Acupuncturists                                                 2.685
# Acute Care Nurses                                              3.060
# ...                                                              ...
# Wind Energy Project Managers                                   3.060
# Wind Turbine Service Technicians                               2.815
# Woodworking Machine Setters, Operators, and Ten...             1.315
# Word Processors and Typists                                    1.750
# Zoologists and Wildlife Biologists                             3.440
#
# element_name                                        Systems Evaluation  \
# title
# Accountants                                                      2.940
# Actors                                                           1.810
# Actuaries                                                        4.250
# Acupuncturists                                                   2.935
# Acute Care Nurses                                                3.125
# ...                                                                ...
# Wind Energy Project Managers                                     3.190
# Wind Turbine Service Technicians                                 2.815
# Woodworking Machine Setters, Operators, and Ten...               1.810
# Word Processors and Typists                                      1.380
# Zoologists and Wildlife Biologists                               3.315
#
# element_name                                        Technology Design  \
# title
# Accountants                                                     1.185
# Actors                                                          0.815
# Actuaries                                                       1.375
# Acupuncturists                                                  1.310
# Acute Care Nurses                                               1.560
# ...                                                               ...
# Wind Energy Project Managers                                    1.375
# Wind Turbine Service Technicians                                1.940
# Woodworking Machine Setters, Operators, and Ten...              1.630
# Word Processors and Typists                                     1.315
# Zoologists and Wildlife Biologists                              1.440
#
# element_name                                        Time Management  \
# title
# Accountants                                                   3.060
# Actors                                                        3.000
# Actuaries                                                     3.310
# Acupuncturists                                                2.685
# Acute Care Nurses                                             3.185
# ...                                                             ...
# Wind Energy Project Managers                                  3.500
# Wind Turbine Service Technicians                              2.815
# Woodworking Machine Setters, Operators, and Ten...            2.435
# Word Processors and Typists                                   2.940
# Zoologists and Wildlife Biologists                            3.565
#
# element_name                                        Troubleshooting  Writing
# title
# Accountants                                                   0.815    3.435
# Actors                                                        0.500    3.130
# Actuaries                                                     0.500    3.690
# Acupuncturists                                                1.125    3.375
# Acute Care Nurses                                             1.810    3.560
# ...                                                             ...      ...
# Wind Energy Project Managers                                  1.690    3.880
# Wind Turbine Service Technicians                              3.750    2.620
# Woodworking Machine Setters, Operators, and Ten...            3.000    1.815
# Word Processors and Typists                                   1.060    3.250
# Zoologists and Wildlife Biologists                            1.065    4.065
#
# [968 rows x 35 columns]

# %% [markdown]
# # K-Means Cluster

# %%
kmeans = KMeans(n_clusters = 7,random_state = 5)
kmeans
# Out:
# KMeans(n_clusters=7, random_state=5)

# %%
Kmodel = kmeans.fit(df_skills)
# Kmodel.labels_

# %%
# Kmodel.cluster_centers_

# %%
def clusters(df,cluster_list):
    '''
    @param: df: dataframe of occupations
            cluster_list: list of different clusters
    returns: dictionary of cluster and their respective occupations 
    '''
    occ_dict = {}
    for i in range(7):
        occ_dict[i] = set()
    
    for occ,cl in zip(df.reset_index()['title'],cluster_list):
        occ_dict[cl].add(occ)
    return occ_dict

# %%
df = reduce(lambda x,y: pd.merge(x,y, on='title', how='outer'), [df_wc,df_knowledge,df_skills,df_gwas,df_jz])
df = df.set_index('title')
df[:20]
# Out:
#                                                     Consequence of Error  \
# title
# Accountants                                                         2.88
# Actors                                                              1.97
# Actuaries                                                           3.28
# Acupuncturists                                                      2.90
# Acute Care Nurses                                                   4.77
# Adapted Physical Education Specialists                              2.47
# Adhesive Bonding Machine Operators and Tenders                      3.82
# Administrative Law Judges, Adjudicators, and He...                  3.20
# Administrative Services Managers                                    2.77
# Adult Basic and Secondary Education and Literac...                  1.97
# Advanced Practice Psychiatric Nurses                                4.17
# Advertising Sales Agents                                            2.00
# Advertising and Promotions Managers                                 2.19
# Aerospace Engineering and Operations Technicians                    3.78
# Aerospace Engineers                                                 2.76
# Agents and Business Managers of Artists, Perfor...                  2.57
# Agricultural Engineers                                              2.88
# Agricultural Equipment Operators                                    2.76
# Agricultural Inspectors                                             3.11
# Agricultural Sciences Teachers, Postsecondary                       2.41
#
#                                                     Contact With Others  \
# title
# Accountants                                                        4.59
# Actors                                                             4.71
# Actuaries                                                          3.62
# Acupuncturists                                                     4.80
# Acute Care Nurses                                                  4.81
# Adapted Physical Education Specialists                             4.31
# Adhesive Bonding Machine Operators and Tenders                     4.61
# Administrative Law Judges, Adjudicators, and He...                 4.60
# Administrative Services Managers                                   4.50
# Adult Basic and Secondary Education and Literac...                 4.27
# Advanced Practice Psychiatric Nurses                               4.59
# Advertising Sales Agents                                           4.79
# Advertising and Promotions Managers                                4.68
# Aerospace Engineering and Operations Technicians                   4.02
# Aerospace Engineers                                                4.24
# Agents and Business Managers of Artists, Perfor...                 4.95
# Agricultural Engineers                                             4.04
# Agricultural Equipment Operators                                   3.68
# Agricultural Inspectors                                            4.61
# Agricultural Sciences Teachers, Postsecondary                      4.16
#
#                                                     Coordinate or Lead Others  \
# title
# Accountants                                                              3.05
# Actors                                                                   3.16
# Adapted Physical Education Specialists                                 2.35
# Adhesive Bonding Machine Operators and Tenders                         4.78
# Administrative Law Judges, Adjudicators, and He...                     1.87
# Administrative Services Managers                                       2.12
# Adult Basic and Secondary Education and Literac...                     1.95
# Advanced Practice Psychiatric Nurses                                   2.17
# Advertising Sales Agents                                               1.20
# Advertising and Promotions Managers                                    1.42
# Aerospace Engineering and Operations Technicians                       3.13
# Aerospace Engineers                                                    2.12
# Agents and Business Managers of Artists, Perfor...                     1.36
# Agricultural Engineers                                                 2.42
# Agricultural Equipment Operators                                       3.65
# Agricultural Inspectors                                                4.10
# Agricultural Sciences Teachers, Postsecondary                          1.68
#
#                                                     ...  \
# title                                               ...
# Accountants                                         ...
# Actors                                              ...
# Actuaries                                           ...
# Acupuncturists                                      ...
# Acute Care Nurses                                   ...
# Adapted Physical Education Specialists              ...
# Adhesive Bonding Machine Operators and Tenders      ...
# Administrative Law Judges, Adjudicators, and He...  ...
# Administrative Services Managers                    ...
# Adult Basic and Secondary Education and Literac...  ...
# Advanced Practice Psychiatric Nurses                ...
# Advertising Sales Agents                            ...
# Advertising and Promotions Managers                 ...
# Aerospace Engineering and Operations Technicians    ...
# Aerospace Engineers                                 ...
# Agents and Business Managers of Artists, Perfor...  ...
# Agricultural Engineers                              ...
# Agricultural Equipment Operators                    ...
# Agricultural Inspectors                             ...
# Agricultural Sciences Teachers, Postsecondary       ...
#
#                                                     Repairing and Maintaining Electronic Equipment  \
# title
# Accountants                                                                                  0.810
# Actors                                                                                       0.850
# Actuaries                                                                                    0.590
# Acupuncturists                                                                               1.225
# Acute Care Nurses                                                                            1.535
# Adapted Physical Education Specialists                                                       1.160
# Adhesive Bonding Machine Operators and Tenders                                               2.390
# Administrative Law Judges, Adjudicators, and He...                                           0.655
# Administrative Services Managers                                                             2.415
# Adult Basic and Secondary Education and Literac...                                           1.315
# Advanced Practice Psychiatric Nurses                                                         0.915
# Advertising Sales Agents                                                                     1.120
# Advertising and Promotions Managers                                                          0.910
# Aerospace Engineering and Operations Technicians                                             3.340
# Aerospace Engineers                                                                          2.250
# Agents and Business Managers of Artists, Perfor...                                           1.110
# Agricultural Engineers                                                                       3.115
# Agricultural Equipment Operators                                                             2.720
# Agricultural Inspectors                                                                      1.650
# Agricultural Sciences Teachers, Postsecondary                                                1.735
#
#                                                     Repairing and Maintaining Mechanical Equipment  \
# title
# Accountants                                                                                  0.830
# Actors                                                                                       0.865
# Actuaries                                                                                    0.500
# Acupuncturists                                                                               1.040
# Acute Care Nurses                                                                            1.225
# Adapted Physical Education Specialists                                                       1.725
# Adhesive Bonding Machine Operators and Tenders                                               3.315
# Administrative Law Judges, Adjudicators, and He...                                           0.600
# Administrative Services Managers                                                             2.500
# Adult Basic and Secondary Education and Literac...                                           1.115
# Advanced Practice Psychiatric Nurses                                                         0.880
# Advertising Sales Agents                                                                     0.590
# Advertising and Promotions Managers                                                          0.935
# Aerospace Engineering and Operations Technicians                                             2.700
# Aerospace Engineers                                                                          1.915
# Agents and Business Managers of Artists, Perfor...                                           0.780
# Agricultural Inspectors                                                             4.185
# Agricultural Sciences Teachers, Postsecondary                                       5.060
#
#                                                     job_zone
# title
# Accountants                                              4.0
# Actors                                                   2.0
# Actuaries                                                4.0
# Acupuncturists                                           5.0
# Acute Care Nurses                                        3.0
# Adapted Physical Education Specialists                   4.0
# Adhesive Bonding Machine Operators and Tenders           2.0
# Administrative Law Judges, Adjudicators, and He...       5.0
# Administrative Services Managers                         3.0
# Adult Basic and Secondary Education and Literac...       4.0
# Advanced Practice Psychiatric Nurses                     5.0
# Advertising Sales Agents                                 4.0
# Advertising and Promotions Managers                      4.0
# Aerospace Engineering and Operations Technicians         3.0
# Aerospace Engineers                                      4.0
# Agents and Business Managers of Artists, Perfor...       4.0
# Agricultural Engineers                                   4.0
# Agricultural Equipment Operators                         1.0
# Agricultural Inspectors                                  2.0
# Agricultural Sciences Teachers, Postsecondary            5.0
#
# [20 rows x 165 columns]

# %%
kmeans = KMeans(n_clusters = 7,random_state = 5)
Kmodel = kmeans.fit(df[:50])

clusters(df[:50],Kmodel.labels_)
# Out:
# {0: {'Acupuncturists',
#   'Acute Care Nurses',
#   'Advanced Practice Psychiatric Nurses',
#   'Allergists and Immunologists',
#   'Anesthesiologist Assistants',
#   'Anesthesiologists'},
#  1: {'Adhesive Bonding Machine Operators and Tenders',
#   'Aerospace Engineering and Operations Technicians',
#   'Agricultural Equipment Operators',
#   'Aircraft Mechanics and Service Technicians',
#   'Aircraft Structure, Surfaces, Rigging, and Systems Assemblers',
#   'Airline Pilots, Copilots, and Flight Engineers'},
#  2: {'Accountants',
#   'Actuaries',
#   'Administrative Law Judges, Adjudicators, and Hearing Officers',
#   'Administrative Services Managers',
#   'Advertising Sales Agents',
#   'Advertising and Promotions Managers',
#   'Agents and Business Managers of Artists, Performers, and Athletes',
#   'Appraisers, Real Estate',
#   'Architectural Drafters',
#   'Archivists',
#   'Art Directors'},
#  3: {'Aerospace Engineers',
#   'Agricultural Engineers',
#   'Agricultural Sciences Teachers, Postsecondary',
#   'Animal Scientists',
#   'Aquacultural Managers',
#   'Architects, Except Landscape and Naval',
#   'Architectural and Engineering Managers',
#   'Architecture Teachers, Postsecondary'},
#  4: {'Anthropologists',
#   'Anthropology and Archeology Teachers, Postsecondary',
#   'Archeologists',
#   'Area, Ethnic, and Cultural Studies Teachers, Postsecondary'},
#  5: {'Agricultural Inspectors',
#   'Agricultural Technicians',
#   'Aircraft Cargo Handling Supervisors',
#   'Airfield Operations Specialists',
#   'Ambulance Drivers and Attendants, Except Emergency Medical Technicians',
#   'Amusement and Recreation Attendants',
#   'Animal Breeders',
#   'Animal Control Workers',
#   'Animal Trainers'},
#  6: {'Actors',
#   'Adapted Physical Education Specialists',
#   'Adult Basic and Secondary Education and Literacy Teachers and Instructors',
#   'Air Traffic Controllers',
#   'Arbitrators, Mediators, and Conciliators',
#   'Art Therapists'}}

# %%
# Next steps: How many clusters? What factors to take into account of?

# %%
# Mean-Shift

# %%
# DBSCAN...not take into account of "noise" (i.e. not so relevant occupations?)
